# %%
import pandas as pd
from matplotlib import pyplot as plt
import seaborn as sns

# %%
# %config InlineBackend.figure_format = 'svg'

# %%
tags = pd.read_csv("Tags.csv", index_col=0)
# Out:
# /usr/lib/python3.9/site-packages/numpy/lib/arraysetops.py:583: FutureWarning: elementwise comparison failed; returning scalar instead, but in the future will perform elementwise comparison
#   mask |= (ar1 == a)

# %%
questions = pd.read_csv("Questions_new.csv", index_col=0, parse_dates=["CreationDate"])
# Out:
# /usr/lib/python3.9/site-packages/numpy/lib/arraysetops.py:583: FutureWarning: elementwise comparison failed; returning scalar instead, but in the future will perform elementwise comparison
#   mask |= (ar1 == a)

# %%
questions["Tags"] = [[]] * len(questions)
for index, body in tags.itertuples():
    questions.at[index, "Tags"] = questions.at[index, "Tags"] + [body]

# %%
answers = pd.read_csv("Answers_new.csv", index_col=0, parse_dates=["CreationDate"])
# Out:
# /usr/lib/python3.9/site-packages/numpy/lib/arraysetops.py:583: FutureWarning: elementwise comparison failed; returning scalar instead, but in the future will perform elementwise comparison
#   mask |= (ar1 == a)

# %%
questions
# Out:
#           OwnerUserId              CreationDate            ClosedDate  Score  \
# Id
# 80               26.0 2008-08-01 13:57:07+00:00                   NaN     26
# 90               58.0 2008-08-01 14:41:24+00:00  2012-12-26T03:45:49Z    144
# 120              83.0 2008-08-01 15:50:08+00:00                   NaN     21
# 180         2089740.0 2008-08-01 18:42:19+00:00                   NaN     53
# 260              91.0 2008-08-01 23:22:08+00:00                   NaN     49
# ...               ...                       ...                   ...    ...
# 40143210    5610777.0 2016-10-19 23:38:01+00:00                   NaN      0
# 40143300    3791161.0 2016-10-19 23:48:09+00:00                   NaN      0
# 40143340    7028647.0 2016-10-19 23:52:50+00:00                   NaN      1
# 40143360     871677.0 2016-10-19 23:55:24+00:00                   NaN      0
# 40143380    6823982.0 2016-10-19 23:57:31+00:00                   NaN      0
#
#                                                       Title  \
# Id
# 80        SQLStatement.execute() - multiple queries in o...
# 90        Good branching and merging tutorials for Torto...
# 120                                       ASP.NET Site Maps
# 180                      Function for creating color wheels
# 260       Adding scripting functionality to .NET applica...
# ...                                                     ...
# 40143210                           URL routing in PHP (MVC)
# 40143300           Bigquery.Jobs.Insert - Resumable Upload?
# 40143340                 Obfuscating code in android studio
# 40143360         How to fire function after v-model change?
# 40143380            npm run mocha test - files being cached
#
#                                                        Body  Length  Answers  \
# Id
# 80        <p>I've written a database generation script i...      72        3
# 90        <p>Are there any really good tutorials explain...      25        3
# 120       <p>Has anyone got experience creating <strong>...      56        1
# 180       <p>This is something I've pseudo-solved many t...      41        9
# 260       <p>I have a little game written in C#. It uses...     169        9
# ...                                                     ...     ...      ...
# 40143210  <p>I am building a custom MVC project and I ha...     104        0
# 40143300  <p>The API docs show that you should be able t...      77        0
# 40143340  <p>Under minifyEnabled I changed from false to...      67        0
# 40143360  <p>I have input which I use to filter my array...     122        0
# 40143380  <p>I'm running a mocha test and I noticed my c...     193        0
#
#                                                        Tags
# Id
# 80                              [flex, actionscript-3, air]
# 90        [svn, tortoisesvn, branch, branching-and-merging]
# 120                                 [sql, asp.net, sitemap]
# 180       [algorithm, language-agnostic, colors, color-s...
# 260            [c#, .net, scripting, compiler-construction]
# ...                                                     ...
# 40143210                                   [php, .htaccess]
# 40143300                                  [google-bigquery]
# 40143340                          [android, android-studio]
# 40143360                               [javascript, vue.js]
# 40143380                                [npm, mocha, babel]
#
# [1264216 rows x 9 columns]

# %%
answers
# Out:
#           OwnerUserId              CreationDate  ParentId  Score  \
# Id
# 92               61.0 2008-08-01 14:45:37+00:00        90     13
# 124              26.0 2008-08-01 16:09:47+00:00        80     12
# 199              50.0 2008-08-01 19:36:46+00:00       180      1
# 269              91.0 2008-08-01 23:49:57+00:00       260      4
# 307              49.0 2008-08-02 01:49:46+00:00       260     28
# ...               ...                       ...       ...    ...
# 40143247     333403.0 2016-10-19 23:42:35+00:00  40143190      0
# 40143322     642706.0 2016-10-19 23:50:35+00:00  40137110      1
# 40143336    2239781.0 2016-10-19 23:52:08+00:00  40141860      0
# 40143349    6934347.0 2016-10-19 23:54:02+00:00  40077010      0
# 40143389    4464432.0 2016-10-19 23:58:58+00:00  40142910      0
#
#                                                        Body
# Id
# 92        <p><a href="http://svnbook.red-bean.com/">Vers...
# 124       <p>I wound up using this. It is a kind of a ha...
# 199       <p>I've read somewhere the human eye can't dis...
# 269       <p>Yes, I thought about that, but I soon figur...
# 307       <p><a href="http://www.codeproject.com/Article...
# ...                                                     ...
# 40143247  <p>Tanks to <a href="http://stackoverflow.com/...
# 40143322  <h1>tl;dr</h1>\n\n<pre><code>ZonedDateTime.par...
# 40143336  <p>I came up with a very dirty workaround. Bef...
# 40143349  <p>I solved my own problem defining the follow...
# 40143389  <p>Try add <code>retrun false</code> in the <c...
#
# [2014516 rows x 5 columns]

# %%
len(questions[questions["Answers"] > 0].index) / len(questions.index)
# Out:
# 0.8721357742664229

# %%
#questions["Answers"] = 0
#answer_question_ids = answers["ParentId"].to_dict().values()
#for i in answer_question_ids:
#    questions.at[i, "Answers"] += 1

# %%
#for index, body in questions["Body"].to_dict().items():
#    questions.at[index, "Length"] = len(body.split("<code>", 1)[0].split())

#for index, body in questions["Body"].to_dict().items():
#    questions.at[index, "Length"] = len("".join(body.split("pre>")[0::2]).split())
#    
#questions.to_csv("Questions_new.csv")

# %%
import numpy as np
max_len = np.percentile(questions["Length"], 90) 

questions_restricted = questions[questions["Length"] <= max_len]
#question_lengths = pd.cut(questions_restricted["Length"], 50)
#graph1 = questions_restricted["Answers"].groupby(question_lengths).mean().plot.line(xlabel="Question Length", ylabel="Mean #Answers")

bins = 50

_, edges = pd.cut(questions_restricted["Length"], bins, retbins=True)
labels = [f'{abs((edges[i] + edges[i+1])/2):.0f}' for i in range(len(edges)-1)]

question_lengths = pd.cut(questions_restricted["Length"], bins, labels=labels)
graph1 = questions_restricted["Answers"].groupby(question_lengths).mean().plot.line(xlabel="Question Length", ylabel="Mean #Answers")

# %%
test = questions[questions["Answers"] > 0]
test2 = test.resample(rule="M", on="CreationDate")["Tags"].sum().explode().groupby("CreationDate").value_counts().reset_index(name="Count").set_index("CreationDate")
test2

# %%
# Tags used by answered questions
test3 = test2.loc['2009-01-01':'2016-08-01'].pivot(columns="Tags", values="Count").fillna(0)
test3[test3.sum().sort_values(ascending=False).head(5).index].plot.line(xlabel="Date", ylabel="Answered questions per month")

# %%
test4 = questions[questions["Answers"] == 0]
test5 = test4.resample(rule="M", on="CreationDate")["Tags"].sum().explode().groupby("CreationDate").value_counts().reset_index(name="Count").set_index("CreationDate")
test5

# %%
# Tags used by unanswered questions
test6 = test5.loc['2009-01-01':'2016-08-01'].pivot(columns="Tags", values="Count").fillna(0)
test6[test6.sum().sort_values(ascending=False).head(5).index].plot.line(xlabel="Date", ylabel="Unanswered questions per month")

# %%
answer_counts = questions.Answers.value_counts()
threshold = 30000
answer_counts_simplified = answer_counts[answer_counts > threshold]
answer_counts_simplified['5 or more'] = answer_counts[answer_counts <= threshold].sum()
answer_counts_simplified.plot.pie(autopct='%1.1f%%')
